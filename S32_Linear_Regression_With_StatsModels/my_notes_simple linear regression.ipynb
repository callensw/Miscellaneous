# %% [markdown]
# # Simple linear regression
#
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('1.01. Simple linear regression.csv')

# %% [markdown]
# - SAT = Critical Reading + Mathematics + Writing
# - GPA = Grade point average (at graduation)

# %% [markdown]
# **Why would I predict GPA with SAT?**
# 1. The SAT is considered one of the best estimators of intellectual capacity and capability
# 2. Almost all colleges across the USA are using the SAT as a proxy for admission
# 3. The SAT stood the test of time

# %% [markdown]
# **We will create a linear regression which predicts GPA based on the SAT score obtained**

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# ## Create your first regression

# %% [markdown]
# ### Define the dependent and independent variables

# %%
y = data['GPA']
x1 = data['SAT']

# %% [markdown]
# ### Explore the data

# %%
plt.scatter(x1, y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %% [markdown]
# In general, the higher the SAT of a student, the higher their GPA

# %% [markdown]
# ### Regression itself

# %%
x = sm.add_constant(x1)

# Results will contain the output of the Ordinary Least Squares (OLS) regression
results = sm.OLS(y,x).fit() # fit() will apply a specific estimation technique (OLS in this case) to obtain the fit of the model
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Mon, 06 Jun 2022   Prob (F-statistic):           7.20e-11
# Time:                        09:22:52   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1, y)
yhat = 0.0017*x1 + 0.275
fig = plt.plot(x1, yhat, lw=4, c='orange', label='regression line')
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %% [markdown]
# Above is the best fitting line, or the line which is closest to all observations simultaneously

# %% [markdown]
# ### Additional Notes

# %% [markdown]
# **Sum of squares total (SST)**
# - Measures the total variability of the dataset
#
# **Sum of squares regression (SSR)**
# - Measures the explained variability by your line
#
# **Sum of squares error (SSE)**
# - Measures the unexplained variability by the regression

# %% [markdown]
# *SST = SSR + SSE*

# %% [markdown]
# - Least squares stands for minimum SSE
#     - Lower error => better explanatory power

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
